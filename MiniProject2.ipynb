# %%
import pandas as pd
df = pd.read_excel(r"C:\Users\DELL\OneDrive\Documents\AI_MARKS.xlsx")
df
# Out:
#              NAME CLASS SECTION  ROLL_NO        PHNO  MARKS  \
# 0      K.SIRI SRI   AIR       A       57  7680862063     91
# 1       U.DEEPIKA   AIR       A       38  6302117978     93
# 2      V.SUSHMITA   AIR       A       46  8074196648     89
# 3       K.KUJITHA   AIR       A       20  7780512016     90
# 4       T.JYOSHNA   AIR       A       22  9059684333     93
# 5       V.PADMINI   AIR       A       40  8688463848     89
# 6  S.DIVYA PAVANI   AIR       A       53  9177129486     88
#
#                        EMAIL_ID
# 0      sirisrikaranam@gmail.com
# 1  deepikalakshmiuppu@gmail.com
# 2   sushmitapenaganti@gmail.com
# 3        kujithakarri@gmail.com
# 4   jyoshnasravaniraj@gmail.com
# 5      velpulapadmini@gmail.com
# 6   divyapavanisaladi@gmail.com

# %%
df.max()
# Out:
# NAME                      V.SUSHMITA
# CLASS                            AIR
# SECTION                            A
# ROLL_NO                           57
# PHNO                      9177129486
# MARKS                             93
# EMAIL_ID    velpulapadmini@gmail.com
# dtype: object

# %%
df.min()
# Out:
# NAME                           K.KUJITHA
# CLASS                                AIR
# SECTION                                A
# ROLL_NO                               20
# PHNO                          6302117978
# MARKS                                 88
# EMAIL_ID    deepikalakshmiuppu@gmail.com
# dtype: object

# %%
df["MARKS"].mean()
# Out:
# 90.42857142857143

# %%
df["MARKS"].mode()
# Out:
# 0    89
# 1    93
# Name: MARKS, dtype: int64

# %%
df["MARKS"].median()
# Out:
# 90.0

# %%
df["MARKS"].var()
# Out:
# 3.952380952380952

# %%
df["MARKS"].std()
# Out:
# 1.9880595947760098

# %%
df["MARKS"].cov(df["ROLL_NO"])
# Out:
# -12.214285714285715
